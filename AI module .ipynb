# %%
# !pip install tensorflow scikit-learn pandas numpy matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error
from tensorflow.keras.layers import Bidirectional

# Mount Google Drive (if using Colab)
from google.colab import drive
drive.mount('/content/drive')

# Load and preprocess data
platform_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Capstone Related/platform_position_1.csv")
satellite_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Capstone Related/satellite_positions_1.csv")

platform_df["Time"] = pd.to_datetime(platform_df["Time"], format="%d-%b-%Y %H:%M:%S", errors="coerce")
satellite_df["Time"] = pd.to_datetime(satellite_df["Time"], format="%d-%b-%Y %H:%M:%S", errors="coerce")

platform_df = platform_df.dropna(subset=["Time"])
satellite_df = satellite_df.dropna(subset=["Time"])

# Merge datasets based on time
merged_df = pd.merge(satellite_df, platform_df, on="Time", suffixes=("_sat", "_plat"))

# Extract time-based feature
merged_df["MinuteOfDay"] = merged_df["Time"].dt.hour * 60 + merged_df["Time"].dt.minute
merged_df["PrevNumConnections"] = merged_df["NumConnections"].shift(1)

# Select features and target variable
features = ["Longitude_sat", "Latitude_sat", "MinuteOfDay"]
target = "NumConnections"
print(merged_df[features].head())
print(merged_df[target].head())

# Normalize the features
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(merged_df[features])

# Define sequence length
sequence_length = 78

# Create time-series sequences
generator = TimeseriesGenerator(scaled_features, merged_df[target].values, length=sequence_length, batch_size=128)

# Define GRU model
def create_gru_model():
    model = Sequential([
    BatchNormalization(input_shape=(sequence_length, len(features))),
    Bidirectional(GRU(512, activation="relu", return_sequences=True)),  # return_sequences=True allows stacking another gru layer
    Dropout(0.2),
    Bidirectional(GRU(256, activation="relu", return_sequences=True)),  # return_sequences=True allows stacking another gru layer
    Dropout(0.2),
    Bidirectional(GRU(128, activation="relu")),  # Adding a second GRU layer
    Dropout(0.2),
    Dense(1,activation="relu")
])
    optimizer = Adam(learning_rate=1e-4, decay=1e-6)
    model.compile(optimizer=optimizer, loss="huber", metrics=["mae"])
    return model

# Cross-validation using TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=5)
mae_scores = []

for train_index, test_index in tscv.split(scaled_features):
    train_data, test_data = scaled_features[train_index], scaled_features[test_index]
    train_target, test_target = merged_df[target].values[train_index], merged_df[target].values[test_index]

    train_generator = TimeseriesGenerator(train_data, train_target, length=sequence_length, batch_size=128)
    test_generator = TimeseriesGenerator(test_data, test_target, length=sequence_length, batch_size=128)

    model = create_gru_model()
    history = model.fit(train_generator, epochs=250, verbose=1, callbacks=[EarlyStopping(monitor='loss', patience=15, restore_best_weights=True)])

    predictions = model.predict(test_generator)
    mae = mean_absolute_error(test_target[sequence_length:], predictions)
    mae_scores.append(mae)
    print(f"MAE for this fold: {mae}")

print(f"Mean MAE across all folds: {np.mean(mae_scores)}")

# Train the final model on the entire dataset
final_model = create_gru_model()
history = final_model.fit(generator, epochs=300, verbose=1, callbacks=[EarlyStopping(monitor='loss', patience=15, restore_best_weights=True)])

# Plot training loss
plt.plot(history.history["loss"], label="Loss")
plt.plot(history.history["mae"], label="MAE")
plt.legend()
plt.title("Training Performance")
plt.show()

# Make predictions
predictions = final_model.predict(generator)

# Plot predictions vs actual values
plt.figure(figsize=(10, 5))
plt.plot(merged_df[target].values[sequence_length:], label="Actual")
plt.plot(predictions, label="Predicted", linestyle="dashed")
plt.legend()
plt.title("GRU Predictions vs Actual")
plt.show()
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Longitude_sat  Latitude_sat  MinuteOfDay
# 0       3.164754   -158.684943            1
# 1       3.164754   -158.684943            1
# 2       3.164754   -158.684943            1
# 3       3.164754   -158.684943            1
# 4       3.164754   -158.684943            1
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: NumConnections, dtype: int64
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/250
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - loss: 2.0151 - mae: 2.1047
# Epoch 2/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 2.8001 - mae: 2.9410
# Epoch 3/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 2.7045 - mae: 2.8668
# Epoch 4/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - loss: 1.9813 - mae: 2.1274
# Epoch 5/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 1.6272 - mae: 1.7690
# Epoch 6/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 1.5744 - mae: 1.7772
# Epoch 7/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - loss: 3.1501 - mae: 3.3805
# Epoch 8/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 2.9455 - mae: 3.1594
# Epoch 9/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 4.8791 - mae: 5.1810
# Epoch 10/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 4.3958 - mae: 4.7188
# Epoch 11/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - loss: 1.6030 - mae: 1.7824
# Epoch 12/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - loss: 4.8626 - mae: 5.1334
# Epoch 13/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 2.8341 - mae: 3.0285
# Epoch 14/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 1.9942 - mae: 2.2347
# Epoch 15/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 4.0507 - mae: 4.3195
# Epoch 16/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 4.2688 - mae: 4.5306
# Epoch 17/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 2.1357 - mae: 2.3573
# Epoch 18/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - loss: 4.6064 - mae: 4.8932
# Epoch 19/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 1.6804 - mae: 1.8230
# Epoch 20/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - loss: 1.6521 - mae: 1.8788
# Epoch 21/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 2.2290 - mae: 2.4270
# Epoch 22/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - loss: 2.7197 - mae: 2.9101
# Epoch 23/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - loss: 1.3711 - mae: 1.5243
# Epoch 24/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 1.3825 - mae: 1.5010
# Epoch 25/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 2.7151 - mae: 3.0427
# Epoch 26/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - loss: 2.8077 - mae: 3.0566
# Epoch 27/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - loss: 1.2274 - mae: 1.3404
# Epoch 28/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 3.7358 - mae: 4.0026
# Epoch 29/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - loss: 0.9264 - mae: 1.0222
# Epoch 30/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - loss: 0.9709 - mae: 1.1340
# Epoch 31/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.6715 - mae: 0.7982
# Epoch 32/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - loss: 0.9758 - mae: 1.1559
# Epoch 33/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - loss: 0.9046 - mae: 1.0665
# Epoch 34/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.9567 - mae: 1.1392
# Epoch 35/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 1.1044 - mae: 1.2354
# Epoch 36/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 1.6539 - mae: 1.9207
# Epoch 37/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - loss: 1.2554 - mae: 1.4118
# Epoch 38/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.7766 - mae: 0.9622
# Epoch 39/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 1.9226 - mae: 2.1598
# Epoch 40/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 1.5511 - mae: 1.7942
# Epoch 41/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - loss: 0.6782 - mae: 0.8073
# Epoch 42/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 10698.6055 - mae: 10698.7676
# Epoch 43/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - loss: 0.9336 - mae: 1.1174
# Epoch 44/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - loss: 0.5931 - mae: 0.7146
# Epoch 45/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.5181 - mae: 0.6583
# Epoch 46/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - loss: 0.3700 - mae: 0.5325
# Epoch 47/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.6281 - mae: 0.7873
# Epoch 48/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.6196 - mae: 0.7961
# Epoch 49/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - loss: 0.5333 - mae: 0.6793
# Epoch 50/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.8832 - mae: 1.1332
# Epoch 51/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.2648 - mae: 0.3567
# Epoch 52/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.1513 - mae: 0.2121
# Epoch 53/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 0.3015 - mae: 0.4065
# Epoch 54/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - loss: 0.1755 - mae: 0.2691
# Epoch 55/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.1730 - mae: 0.2446
# Epoch 56/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - loss: 0.2769 - mae: 0.3723
# Epoch 57/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - loss: 0.1457 - mae: 0.2140
# Epoch 58/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.3061 - mae: 0.4481
# Epoch 59/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - loss: 0.3517 - mae: 0.5035
# Epoch 60/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 0.1070 - mae: 0.1505
# Epoch 61/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.1497 - mae: 0.2169
# Epoch 62/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - loss: 0.1256 - mae: 0.1873
# Epoch 63/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.1782 - mae: 0.2702
# Epoch 64/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.1989 - mae: 0.2931
# Epoch 65/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - loss: 0.1149 - mae: 0.1708
# Epoch 66/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - loss: 0.4130 - mae: 0.6096
# Epoch 67/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - loss: 0.1731 - mae: 0.2597
# Epoch 68/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - loss: 0.3066 - mae: 0.4507
# Epoch 69/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - loss: 0.2199 - mae: 0.3376
# Epoch 70/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.2028 - mae: 0.2942
# Epoch 71/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.0845 - mae: 0.1245
# Epoch 72/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - loss: 0.1731 - mae: 0.2559
# Epoch 73/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - loss: 0.1592 - mae: 0.2392
# Epoch 74/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.1100 - mae: 0.1655
# Epoch 75/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 0.2740 - mae: 0.4004
# Epoch 76/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.1702 - mae: 0.2567
# Epoch 77/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.0804 - mae: 0.1261
# Epoch 78/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.1134 - mae: 0.1625
# Epoch 79/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 0.0997 - mae: 0.1456
# Epoch 80/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.3789 - mae: 0.5605
# Epoch 81/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.3168 - mae: 0.4075
# Epoch 82/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.1951 - mae: 0.2824
# Epoch 83/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.4157 - mae: 0.6183
# Epoch 84/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.1365 - mae: 0.2010
# Epoch 85/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.1567 - mae: 0.2205
# Epoch 86/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.2684 - mae: 0.4038
# Epoch 87/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.3617 - mae: 0.5340
# Epoch 88/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - loss: 0.2398 - mae: 0.3531
# Epoch 89/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.2935 - mae: 0.4667
# Epoch 90/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - loss: 0.1408 - mae: 0.2088
# Epoch 91/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - loss: 0.1538 - mae: 0.2330
# Epoch 92/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.2403 - mae: 0.3652
# Epoch 93/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.1360 - mae: 0.1957
# Epoch 94/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.2080 - mae: 0.3147
# Epoch 95/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.3339 - mae: 0.4640
# Epoch 96/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.2218 - mae: 0.3193
# Epoch 97/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.1665 - mae: 0.2385
# Epoch 98/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - loss: 0.1456 - mae: 0.2281
# Epoch 99/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.3281 - mae: 0.4819
# Epoch 100/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - loss: 0.2216 - mae: 0.3276
# Epoch 101/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - loss: 0.1318 - mae: 0.2149
# Epoch 102/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.1865 - mae: 0.2791
# Epoch 103/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.1366 - mae: 0.2172
# Epoch 104/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.1826 - mae: 0.2902
# Epoch 105/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.1475 - mae: 0.2285
# Epoch 106/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 173ms/step - loss: 0.2070 - mae: 0.3274
# Epoch 107/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.1216 - mae: 0.1815
# Epoch 108/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.2321 - mae: 0.3374
# Epoch 109/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.2862 - mae: 0.4510
# Epoch 110/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - loss: 0.4215 - mae: 0.6066
# Epoch 111/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step - loss: 0.1218 - mae: 0.1863
# Epoch 112/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.1476 - mae: 0.2194
# Epoch 113/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - loss: 0.1196 - mae: 0.1765
# Epoch 114/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.1803 - mae: 0.2816
# Epoch 115/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.2390 - mae: 0.3617
# Epoch 116/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.2734 - mae: 0.4410
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 423ms/step
# MAE for this fold: 0.9623657464981079
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/250
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 26s 915ms/step - loss: 0.9300 - mae: 0.9795
# Epoch 2/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - loss: 1.1577 - mae: 1.2252
# Epoch 3/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 170ms/step - loss: 2.5100 - mae: 2.6253
# Epoch 4/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - loss: 3.2039 - mae: 3.3492
# Epoch 5/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: 2.3617 - mae: 2.4779
# Epoch 6/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - loss: 2.6898 - mae: 2.8254
# Epoch 7/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - loss: 2.1351 - mae: 2.2504
# Epoch 8/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - loss: 0.5568 - mae: 0.5838
# Epoch 9/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - loss: 1.5578 - mae: 1.6288
# Epoch 10/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - loss: 4.2248 - mae: 4.4276
# Epoch 11/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - loss: 0.4654 - mae: 0.4940
# Epoch 12/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 173ms/step - loss: 1.3945 - mae: 1.4602
# Epoch 13/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - loss: 2.5817 - mae: 2.7029
# Epoch 14/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - loss: 3.5513 - mae: 3.7141
# Epoch 15/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - loss: 3.2336 - mae: 3.3851
# Epoch 16/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - loss: 1.6915 - mae: 1.7696
# Epoch 17/250
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 177ms/step - loss: 2.5193 - mae: 2.6610
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 376ms/step
# MAE for this fold: 0.5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/250
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 26s 637ms/step - loss: 1.2532 - mae: 1.3150
# Epoch 2/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 1.6036 - mae: 1.6813
# Epoch 3/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 1.4593 - mae: 1.5265
# Epoch 4/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 1.1841 - mae: 1.2408
# Epoch 5/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: 1.4591 - mae: 1.5293
# Epoch 6/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 1.3918 - mae: 1.4620
# Epoch 7/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: 1.8371 - mae: 1.9261
# Epoch 8/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 2.3089 - mae: 2.4163
# Epoch 9/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 1.8570 - mae: 1.9456
# Epoch 10/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: 1.7987 - mae: 1.8861
# Epoch 11/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: 1.1948 - mae: 1.2544
# Epoch 12/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 0.9849 - mae: 1.0363
# Epoch 13/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: 1.5039 - mae: 1.5748
# Epoch 14/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - loss: 1.8978 - mae: 1.9917
# Epoch 15/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - loss: 1.0696 - mae: 1.1216
# Epoch 16/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 1.1554 - mae: 1.2087
# Epoch 17/250
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - loss: 1.3367 - mae: 1.4045
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 557ms/step
# MAE for this fold: 2.9629628658294678
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/250
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 29s 515ms/step - loss: 0.9702 - mae: 1.0359
# Epoch 2/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 2.7338 - mae: 3.0002
# Epoch 3/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 2.3846 - mae: 2.6387
# Epoch 4/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 1.7658 - mae: 1.9724
# Epoch 5/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.7909 - mae: 0.9950
# Epoch 6/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 1.7118 - mae: 1.9400
# Epoch 7/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 1.8790 - mae: 2.1163
# Epoch 8/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 1.8533 - mae: 2.0571
# Epoch 9/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 1.9561 - mae: 2.1776
# Epoch 10/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.9431 - mae: 1.0833
# Epoch 11/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 2.5519 - mae: 2.8322
# Epoch 12/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 1.7857 - mae: 1.9094
# Epoch 13/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.6116 - mae: 0.7272
# Epoch 14/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 2.7025 - mae: 2.9608
# Epoch 15/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.9458 - mae: 1.0322
# Epoch 16/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 1.6273 - mae: 1.7986
# Epoch 17/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 1.2376 - mae: 1.4137
# Epoch 18/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - loss: 0.7441 - mae: 0.8621
# Epoch 19/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.6558 - mae: 0.7763
# Epoch 20/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.4458 - mae: 0.5230
# Epoch 21/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.7846 - mae: 0.9128
# Epoch 22/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - loss: 0.4920 - mae: 0.5901
# Epoch 23/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - loss: 0.3964 - mae: 0.4998
# Epoch 24/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.6145 - mae: 0.7035
# Epoch 25/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.4114 - mae: 0.5051
# Epoch 26/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.3272 - mae: 0.4279
# Epoch 27/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.3174 - mae: 0.4110
# Epoch 28/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.2832 - mae: 0.3659
# Epoch 29/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.2130 - mae: 0.2891
# Epoch 30/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.5387 - mae: 0.6529
# Epoch 31/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.6925 - mae: 0.8306
# Epoch 32/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.3154 - mae: 0.4143
# Epoch 33/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.1268 - mae: 0.1715
# Epoch 34/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.2866 - mae: 0.3615
# Epoch 35/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.4989 - mae: 0.6447
# Epoch 36/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.3555 - mae: 0.4722
# Epoch 37/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.4551 - mae: 0.5441
# Epoch 38/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.2855 - mae: 0.3741
# Epoch 39/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.4947 - mae: 0.6102
# Epoch 40/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.2555 - mae: 0.3353
# Epoch 41/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.2638 - mae: 0.3438
# Epoch 42/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.2045 - mae: 0.2694
# Epoch 43/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - loss: 0.2086 - mae: 0.2718
# Epoch 44/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.2372 - mae: 0.3094
# Epoch 45/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.2654 - mae: 0.3289
# Epoch 46/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.2987 - mae: 0.3821
# Epoch 47/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.5415 - mae: 0.6815
# Epoch 48/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.2038 - mae: 0.2706
# Epoch 49/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.2948 - mae: 0.4202
# Epoch 50/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.4581 - mae: 0.5609
# Epoch 51/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.3924 - mae: 0.5191
# Epoch 52/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.3850 - mae: 0.4906
# Epoch 53/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.2440 - mae: 0.3348
# Epoch 54/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.3160 - mae: 0.4125
# Epoch 55/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.3101 - mae: 0.4030
# Epoch 56/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.1084 - mae: 0.1443
# Epoch 57/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.3638 - mae: 0.5029
# Epoch 58/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - loss: 0.3789 - mae: 0.4772
# Epoch 59/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.4256 - mae: 0.5209
# Epoch 60/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.3542 - mae: 0.4349
# Epoch 61/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.5972 - mae: 0.7494
# Epoch 62/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.3168 - mae: 0.4163
# Epoch 63/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.2467 - mae: 0.3235
# Epoch 64/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.2249 - mae: 0.3007
# Epoch 65/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.2859 - mae: 0.3638
# Epoch 66/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - loss: 0.1361 - mae: 0.1836
# Epoch 67/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - loss: 0.3915 - mae: 0.5117
# Epoch 68/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.2890 - mae: 0.3987
# Epoch 69/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - loss: 0.2399 - mae: 0.3149
# Epoch 70/250
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - loss: 0.2132 - mae: 0.2908
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 386ms/step
# MAE for this fold: 0.0
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/250
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 27s 409ms/step - loss: 1.1962 - mae: 1.2567
# Epoch 2/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - loss: 1.9512 - mae: 2.0457
# Epoch 3/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - loss: 1.4663 - mae: 1.5510
# Epoch 4/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - loss: 2.0185 - mae: 2.1229
# Epoch 5/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - loss: 0.8661 - mae: 0.9240
# Epoch 6/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - loss: 1.3364 - mae: 1.4075
# Epoch 7/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - loss: 0.7795 - mae: 0.8215
# Epoch 8/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step - loss: 0.9740 - mae: 1.0237
# Epoch 9/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - loss: 1.1840 - mae: 1.2481
# Epoch 10/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - loss: 2.1070 - mae: 2.2142
# Epoch 11/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - loss: 1.4984 - mae: 1.5775
# Epoch 12/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - loss: 1.6851 - mae: 1.7669
# Epoch 13/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - loss: 1.5475 - mae: 1.6258
# Epoch 14/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - loss: 1.4171 - mae: 1.5000
# Epoch 15/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - loss: 1.2153 - mae: 1.2903
# Epoch 16/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - loss: 1.8595 - mae: 1.9462
# Epoch 17/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - loss: 1.9575 - mae: 2.0546
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 458ms/step
# MAE for this fold: 3.0185184478759766
# Mean MAE across all folds: 1.4887694120407104
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/300
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 29s 384ms/step - loss: 1.9511 - mae: 2.1003
# Epoch 2/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 179ms/step - loss: 1.9922 - mae: 2.2190
# Epoch 3/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - loss: 2.7569 - mae: 3.0056
# Epoch 4/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 180ms/step - loss: 2.0204 - mae: 2.2291
# Epoch 5/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 180ms/step - loss: 1.3440 - mae: 1.5085
# Epoch 6/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 179ms/step - loss: 1.7532 - mae: 1.9799
# Epoch 7/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 177ms/step - loss: 1.2863 - mae: 1.4139
# Epoch 8/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 177ms/step - loss: 1.7241 - mae: 1.9141
# Epoch 9/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 177ms/step - loss: 1.5033 - mae: 1.6645
# Epoch 10/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 1.3300 - mae: 1.4682
# Epoch 11/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 1.3018 - mae: 1.4479
# Epoch 12/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 1.5478 - mae: 1.6973
# Epoch 13/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 1.1652 - mae: 1.3284
# Epoch 14/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 1.6214 - mae: 1.7852
# Epoch 15/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.8094 - mae: 0.8948
# Epoch 16/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 1.0011 - mae: 1.0909
# Epoch 17/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 1.1458 - mae: 1.2931
# Epoch 18/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.6688 - mae: 0.7616
# Epoch 19/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.5093 - mae: 0.6119
# Epoch 20/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - loss: 0.4899 - mae: 0.5696
# Epoch 21/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - loss: 0.4377 - mae: 0.5389
# Epoch 22/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.4157 - mae: 0.5292
# Epoch 23/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.7781 - mae: 0.9071
# Epoch 24/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.4180 - mae: 0.4772
# Epoch 25/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.3779 - mae: 0.4622
# Epoch 26/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.5389 - mae: 0.6294
# Epoch 27/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.4555 - mae: 0.5384
# Epoch 28/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.4172 - mae: 0.5227
# Epoch 29/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.5274 - mae: 0.6125
# Epoch 30/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2815 - mae: 0.3497
# Epoch 31/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.3589 - mae: 0.4347
# Epoch 32/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2003 - mae: 0.2448
# Epoch 33/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.3503 - mae: 0.4261
# Epoch 34/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2699 - mae: 0.3361
# Epoch 35/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.3132 - mae: 0.3897
# Epoch 36/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.5301 - mae: 0.6395
# Epoch 37/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - loss: 0.3888 - mae: 0.4764
# Epoch 38/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - loss: 0.3902 - mae: 0.4916
# Epoch 39/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2864 - mae: 0.3479
# Epoch 40/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.2449 - mae: 0.3042
# Epoch 41/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.3843 - mae: 0.4872
# Epoch 42/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.9533 - mae: 1.1064
# Epoch 43/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.3593 - mae: 0.4575
# Epoch 44/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.5080 - mae: 0.6033
# Epoch 45/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.3711 - mae: 0.4288
# Epoch 46/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.3763 - mae: 0.4432
# Epoch 47/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2665 - mae: 0.3362
# Epoch 48/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.2899 - mae: 0.3556
# Epoch 49/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.5220 - mae: 0.5951
# Epoch 50/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.3314 - mae: 0.3913
# Epoch 51/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.3434 - mae: 0.3968
# Epoch 52/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - loss: 0.8285 - mae: 0.9626
# Epoch 53/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - loss: 0.2909 - mae: 0.3468
# Epoch 54/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2405 - mae: 0.2971
# Epoch 55/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.1817 - mae: 0.2248
# Epoch 56/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.2795 - mae: 0.3784
# Epoch 57/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.5416 - mae: 0.6331
# Epoch 58/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - loss: 0.4010 - mae: 0.4878
# Epoch 59/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.3828 - mae: 0.4432
# Epoch 60/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.4821 - mae: 0.5692
# Epoch 61/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.3618 - mae: 0.4623
# Epoch 62/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.3870 - mae: 0.4695
# Epoch 63/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.3344 - mae: 0.4150
# Epoch 64/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2644 - mae: 0.3389
# Epoch 65/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.2771 - mae: 0.3477
# Epoch 66/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.6088 - mae: 0.7309
# Epoch 67/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.2112 - mae: 0.2666
# Epoch 68/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.2510 - mae: 0.3031
# Epoch 69/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - loss: 0.4168 - mae: 0.5177
# Epoch 70/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.6289 - mae: 0.7319
# Epoch 71/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.3717 - mae: 0.4584
# Epoch 72/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - loss: 0.5918 - mae: 0.6878
# Epoch 73/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.2562 - mae: 0.3217
# Epoch 74/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.3871 - mae: 0.4754
# Epoch 75/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.6119 - mae: 0.6888
# Epoch 76/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.4104 - mae: 0.4998
# Epoch 77/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.3635 - mae: 0.4594
# Epoch 78/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.3330 - mae: 0.3952
# Epoch 79/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.3565 - mae: 0.4340
# Epoch 80/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.1745 - mae: 0.2153
# Epoch 81/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.5354 - mae: 0.6528
# Epoch 82/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.1434 - mae: 0.2096
# Epoch 83/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.4804 - mae: 0.5749
# Epoch 84/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 172ms/step - loss: 0.9473 - mae: 1.0550
# Epoch 85/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.5955 - mae: 0.6994
# Epoch 86/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.2276 - mae: 0.2827
# Epoch 87/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.5273 - mae: 0.5887
# Epoch 88/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.4223 - mae: 0.5017
# Epoch 89/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2576 - mae: 0.3314
# Epoch 90/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.2085 - mae: 0.2687
# Epoch 91/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.3975 - mae: 0.5099
# Epoch 92/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.2792 - mae: 0.3254
# Epoch 93/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2695 - mae: 0.3325
# Epoch 94/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.4201 - mae: 0.5208
# Epoch 95/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2685 - mae: 0.3282
# Epoch 96/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.3478 - mae: 0.4539
# Epoch 97/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.3161 - mae: 0.4074
# Epoch 98/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.2112 - mae: 0.2781
# Epoch 99/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2435 - mae: 0.3095
# Epoch 100/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.3065 - mae: 0.3813
# Epoch 101/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2722 - mae: 0.3300
# Epoch 102/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.3669 - mae: 0.4674
# Epoch 103/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.5417 - mae: 0.6189
# Epoch 104/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - loss: 0.3280 - mae: 0.3931
# Epoch 105/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - loss: 0.6579 - mae: 0.7355
# Epoch 106/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.3683 - mae: 0.4193
# Epoch 107/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.4611 - mae: 0.5427
# Epoch 108/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.4597 - mae: 0.5642
# Epoch 109/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2617 - mae: 0.3344
# Epoch 110/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.2525 - mae: 0.3349
# Epoch 111/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2964 - mae: 0.3973
# Epoch 112/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.2429 - mae: 0.3229
# Epoch 113/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2874 - mae: 0.3801
# Epoch 114/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2328 - mae: 0.3080
# Epoch 115/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.2461 - mae: 0.3376
# Epoch 116/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.1968 - mae: 0.2800
# Epoch 117/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - loss: 0.1396 - mae: 0.1972
# Epoch 118/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.1731 - mae: 0.2444
# Epoch 119/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.1693 - mae: 0.2165
# Epoch 120/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2170 - mae: 0.3197
# Epoch 121/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.2318 - mae: 0.3062
# Epoch 122/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2346 - mae: 0.3222
# Epoch 123/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.1119 - mae: 0.1659
# Epoch 124/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - loss: 0.1897 - mae: 0.2698
# Epoch 125/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2793 - mae: 0.3714
# Epoch 126/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.7644 - mae: 0.9007
# Epoch 127/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.4209 - mae: 0.4722
# Epoch 128/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.5896 - mae: 0.6487
# Epoch 129/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.6306 - mae: 0.7328
# Epoch 130/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.3345 - mae: 0.3870
# Epoch 131/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.4360 - mae: 0.5273
# Epoch 132/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - loss: 0.6066 - mae: 0.6830
# Epoch 133/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - loss: 0.3270 - mae: 0.3939
# Epoch 134/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.3826 - mae: 0.4478
# Epoch 135/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.3469 - mae: 0.4342
# Epoch 136/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - loss: 0.3633 - mae: 0.4822
# Epoch 137/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.2858 - mae: 0.3591
# Epoch 138/300
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.6133 - mae: 0.7345
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 109ms/step

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error

# Mount Google Drive (if using Colab)
from google.colab import drive
drive.mount('/content/drive')

# Load and preprocess data
platform_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Capstone Related/platform_position_1.csv")
satellite_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Capstone Related/satellite_positions_1.csv")

platform_df["Time"] = pd.to_datetime(platform_df["Time"], format="%d-%b-%Y %H:%M:%S", errors="coerce")
satellite_df["Time"] = pd.to_datetime(satellite_df["Time"], format="%d-%b-%Y %H:%M:%S", errors="coerce")

platform_df = platform_df.dropna(subset=["Time"])
satellite_df = satellite_df.dropna(subset=["Time"])

# Merge datasets based on time
merged_df = pd.merge(satellite_df, platform_df, on="Time", suffixes=("_sat", "_plat"))

# Extract time-based feature
merged_df["MinuteOfDay"] = merged_df["Time"].dt.hour * 60 + merged_df["Time"].dt.minute

# Select features and target variable
features = ["Longitude_sat", "Latitude_sat", "MinuteOfDay"]
target = "NumConnections"
print(merged_df[features].head())
print(merged_df[target].head())

# Normalize the features
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(merged_df[features])

# Define sequence length
sequence_length = 80

# Create time-series sequences
generator = TimeseriesGenerator(scaled_features, merged_df[target].values, length=sequence_length, batch_size=128)

# Define RNN model
def create_rnn_model():
    model = Sequential([
        BatchNormalization(input_shape=(sequence_length, len(features))),
        Bidirectional(SimpleRNN(256, activation="relu", return_sequences=True)),  # Using SimpleRNN instead of GRU
        Dropout(0.2),
        Bidirectional(SimpleRNN(128, activation="relu", return_sequences=True)),  # Adding a second RNN layer
        Dropout(0.2),
        Bidirectional(SimpleRNN(64, activation="relu")),  # Adding a second RNN layer
        Dropout(0.2),
        Dense(1,activation="relu")
    ])
    optimizer = Adam(learning_rate=1e-4, decay=1e-6)
    model.compile(optimizer=optimizer, loss="huber", metrics=["mae"])
    return model

# Cross-validation using TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=5)
mae_scores = []

for train_index, test_index in tscv.split(scaled_features):
    train_data, test_data = scaled_features[train_index], scaled_features[test_index]
    train_target, test_target = merged_df[target].values[train_index], merged_df[target].values[test_index]

    train_generator = TimeseriesGenerator(train_data, train_target, length=sequence_length, batch_size=128)
    test_generator = TimeseriesGenerator(test_data, test_target, length=sequence_length, batch_size=128)

    model = create_rnn_model()
    history = model.fit(train_generator, epochs=150, verbose=1, callbacks=[EarlyStopping(monitor='loss', patience=15, restore_best_weights=True)])

    predictions = model.predict(test_generator)
    mae = mean_absolute_error(test_target[sequence_length:], predictions)
    mae_scores.append(mae)
    print(f"MAE for this fold: {mae}")

print(f"Mean MAE across all folds: {np.mean(mae_scores)}")

# Train the final model on the entire dataset
final_model = create_rnn_model()
history = final_model.fit(generator, epochs=200, verbose=1, callbacks=[EarlyStopping(monitor='loss', patience=15, restore_best_weights=True)])

# Plot training loss
plt.plot(history.history["loss"], label="Loss")
plt.plot(history.history["mae"], label="MAE")
plt.legend()
plt.title("Training Performance")
plt.show()

# Make predictions
predictions = final_model.predict(generator)

# Plot predictions vs actual values
plt.figure(figsize=(10, 5))
plt.plot(merged_df[target].values[sequence_length:], label="Actual")
plt.plot(predictions, label="Predicted", linestyle="dashed")
plt.legend()
plt.title("RNN Predictions vs Actual")
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Longitude_sat  Latitude_sat  MinuteOfDay
# 0       3.164754   -158.684943            1
# 1       3.164754   -158.684943            1
# 2       3.164754   -158.684943            1
# 3       3.164754   -158.684943            1
# 4       3.164754   -158.684943            1
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: NumConnections, dtype: int64
# Epoch 1/150
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - loss: 4.9705 - mae: 5.2462
# Epoch 2/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - loss: 3.0403 - mae: 3.2466
# Epoch 3/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.2744 - mae: 1.4019
# Epoch 4/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 4.5872 - mae: 4.8347
# Epoch 5/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 1.7002 - mae: 1.8897
# Epoch 6/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.5702 - mae: 1.7396
# Epoch 7/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 3.6371 - mae: 3.8783
# Epoch 8/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.9613 - mae: 2.1028
# Epoch 9/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.6912 - mae: 2.8955
# Epoch 10/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 3.0049 - mae: 3.2058
# Epoch 11/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 2.3089 - mae: 2.4664
# Epoch 12/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 2.0592 - mae: 2.2289
# Epoch 13/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 2.9395 - mae: 3.1615
# Epoch 14/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1.7937 - mae: 1.9961
# Epoch 15/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.8557 - mae: 0.9821
# Epoch 16/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 2.9471 - mae: 3.2551
# Epoch 17/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 2.4087 - mae: 2.6023
# Epoch 18/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 2.7000 - mae: 2.9120
# Epoch 19/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.1234 - mae: 1.2136
# Epoch 20/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.7613 - mae: 0.8831
# Epoch 21/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1.8082 - mae: 2.0324
# Epoch 22/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.4819 - mae: 1.6633
# Epoch 23/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.7695 - mae: 0.9111
# Epoch 24/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.6217 - mae: 0.7301
# Epoch 25/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.9804 - mae: 1.1942
# Epoch 26/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.7368 - mae: 0.8689
# Epoch 27/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.8566 - mae: 0.9678
# Epoch 28/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.1436 - mae: 1.3614
# Epoch 29/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.7948 - mae: 0.9013
# Epoch 30/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.2063 - mae: 1.3788
# Epoch 31/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.7888 - mae: 0.9376
# Epoch 32/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.3569 - mae: 0.4665
# Epoch 33/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.9753 - mae: 1.1416
# Epoch 34/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4481 - mae: 0.5326
# Epoch 35/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4900 - mae: 0.5741
# Epoch 36/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.6213 - mae: 0.7057
# Epoch 37/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.8545 - mae: 0.9677
# Epoch 38/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.6060 - mae: 0.7724
# Epoch 39/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.4873 - mae: 0.5947
# Epoch 40/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.8340 - mae: 0.9964
# Epoch 41/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.5131 - mae: 0.6109
# Epoch 42/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.3235 - mae: 0.3984
# Epoch 43/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.9999 - mae: 1.1701
# Epoch 44/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.7593 - mae: 1.9484
# Epoch 45/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.8659 - mae: 0.9491
# Epoch 46/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.8984 - mae: 2.0414
# Epoch 47/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.2779 - mae: 1.4502
# Epoch 48/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.5685 - mae: 1.7743
# Epoch 49/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.4352 - mae: 0.5436
# Epoch 50/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.3823 - mae: 1.5647
# Epoch 51/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.8701 - mae: 1.0032
# Epoch 52/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.3449 - mae: 0.4285
# Epoch 53/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.8363 - mae: 0.9645
# Epoch 54/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.6259 - mae: 0.7542
# Epoch 55/150
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.6183 - mae: 0.7398
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 247ms/step
# MAE for this fold: 2.2890217304229736
# Epoch 1/150
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 16s 512ms/step - loss: 0.5712 - mae: 0.6531
# Epoch 2/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.1940 - mae: 2.3346
# Epoch 3/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 3.4456 - mae: 3.6721
# Epoch 4/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.7011 - mae: 1.9066
# Epoch 5/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.2544 - mae: 2.4260
# Epoch 6/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.6237 - mae: 1.8405
# Epoch 7/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.3961 - mae: 3.6949
# Epoch 8/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.1797 - mae: 3.4285
# Epoch 9/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.0818 - mae: 1.2107
# Epoch 10/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.2700 - mae: 1.4604
# Epoch 11/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.5076 - mae: 1.7528
# Epoch 12/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.6392 - mae: 1.8290
# Epoch 13/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.0398 - mae: 1.1719
# Epoch 14/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.0030 - mae: 1.1079
# Epoch 15/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.4987 - mae: 1.6580
# Epoch 16/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.3023 - mae: 1.4317
# Epoch 17/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.7582 - mae: 0.8376
# Epoch 18/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.0020 - mae: 2.2877
# Epoch 19/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.7332 - mae: 0.8783
# Epoch 20/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.6104 - mae: 0.7462
# Epoch 21/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.1581 - mae: 1.3180
# Epoch 22/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.6721 - mae: 0.7533
# Epoch 23/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5216 - mae: 0.6510
# Epoch 24/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.8808 - mae: 2.0762
# Epoch 25/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.1733 - mae: 1.3879
# Epoch 26/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.7349 - mae: 0.8482
# Epoch 27/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3805 - mae: 0.4686
# Epoch 28/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3622 - mae: 0.4733
# Epoch 29/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2476 - mae: 0.2806
# Epoch 30/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.5222 - mae: 0.5970
# Epoch 31/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3973 - mae: 0.4662
# Epoch 32/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2612 - mae: 0.3142
# Epoch 33/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4075 - mae: 0.4852
# Epoch 34/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.7126 - mae: 0.8245
# Epoch 35/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.5028 - mae: 1.6160
# Epoch 36/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.7702 - mae: 0.8672
# Epoch 37/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.7950 - mae: 0.9046
# Epoch 38/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3934 - mae: 0.4676
# Epoch 39/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.8742 - mae: 0.9726
# Epoch 40/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4357 - mae: 0.5079
# Epoch 41/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.6209 - mae: 0.7529
# Epoch 42/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.7496 - mae: 0.8662
# Epoch 43/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4418 - mae: 0.5173
# Epoch 44/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.8246 - mae: 0.9400
# Epoch 45/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2849 - mae: 0.3388
# Epoch 46/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.6087 - mae: 0.7120
# Epoch 47/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.8584 - mae: 0.9652
# Epoch 48/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.3703 - mae: 1.5574
# Epoch 49/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5922 - mae: 0.7042
# Epoch 50/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3117 - mae: 0.3728
# Epoch 51/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2914 - mae: 0.3553
# Epoch 52/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.3292 - mae: 1.4983
# Epoch 53/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4820 - mae: 0.5701
# Epoch 54/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.0910 - mae: 1.2209
# Epoch 55/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.3654 - mae: 1.5409
# Epoch 56/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.3313 - mae: 1.5042
# Epoch 57/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.7319 - mae: 0.8373
# Epoch 58/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2600 - mae: 0.3129
# Epoch 59/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2761 - mae: 0.3332
# Epoch 60/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6381 - mae: 0.7249
# Epoch 61/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3503 - mae: 0.4208
# Epoch 62/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5290 - mae: 0.6530
# Epoch 63/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.1953 - mae: 0.2459
# Epoch 64/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.5766 - mae: 0.6919
# Epoch 65/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.4758 - mae: 0.5995
# Epoch 66/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2315 - mae: 0.2733
# Epoch 67/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.7034 - mae: 0.7977
# Epoch 68/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.4459 - mae: 0.5228
# Epoch 69/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.8591 - mae: 0.9885
# Epoch 70/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.9646 - mae: 1.1023
# Epoch 71/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1165 - mae: 0.1400
# Epoch 72/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5140 - mae: 0.5960
# Epoch 73/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.5771 - mae: 0.6707
# Epoch 74/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2016 - mae: 0.2480
# Epoch 75/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.1884 - mae: 1.3184
# Epoch 76/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3904 - mae: 0.4753
# Epoch 77/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.1135 - mae: 1.2552
# Epoch 78/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3339 - mae: 0.4168
# Epoch 79/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.5463 - mae: 0.6485
# Epoch 80/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2616 - mae: 0.3087
# Epoch 81/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.7074 - mae: 0.8132
# Epoch 82/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6516 - mae: 0.7590
# Epoch 83/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5140 - mae: 0.5871
# Epoch 84/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3735 - mae: 0.4219
# Epoch 85/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.1308 - mae: 1.2557
# Epoch 86/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.1004 - mae: 1.2416
# Epoch 87/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3916 - mae: 0.4421
# Epoch 88/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.1453 - mae: 0.1764
# Epoch 89/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.4340 - mae: 0.5166
# Epoch 90/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3041 - mae: 0.3736
# Epoch 91/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.2917 - mae: 1.4487
# Epoch 92/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.4834 - mae: 0.5996
# Epoch 93/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.2602 - mae: 1.3983
# Epoch 94/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2042 - mae: 0.2532
# Epoch 95/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5058 - mae: 0.5701
# Epoch 96/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4080 - mae: 0.4761
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step
# MAE for this fold: 0.47285714745521545
# Epoch 1/150
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 17s 352ms/step - loss: 3.1466 - mae: 3.3816
# Epoch 2/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.2949 - mae: 1.4387
# Epoch 3/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.5286 - mae: 1.6832
# Epoch 4/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.2256 - mae: 2.4169
# Epoch 5/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.4732 - mae: 1.6550
# Epoch 6/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.7034 - mae: 1.8830
# Epoch 7/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.1513 - mae: 1.2842
# Epoch 8/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.7396 - mae: 2.9912
# Epoch 9/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.4789 - mae: 1.6533
# Epoch 10/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.1587 - mae: 1.3103
# Epoch 11/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.6187 - mae: 1.7827
# Epoch 12/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.2290 - mae: 1.3414
# Epoch 13/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.4594 - mae: 3.7214
# Epoch 14/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.7909 - mae: 1.9325
# Epoch 15/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.8713 - mae: 3.0679
# Epoch 16/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 2.2534 - mae: 2.3995
# Epoch 17/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.4562 - mae: 0.5109
# Epoch 18/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.2670 - mae: 1.4611
# Epoch 19/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.0916 - mae: 1.1870
# Epoch 20/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.9003 - mae: 0.9839
# Epoch 21/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5862 - mae: 0.6751
# Epoch 22/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.1501 - mae: 1.2400
# Epoch 23/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.5812 - mae: 1.7494
# Epoch 24/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.8593 - mae: 0.9457
# Epoch 25/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.7722 - mae: 1.9125
# Epoch 26/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.7606 - mae: 0.8834
# Epoch 27/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.8370 - mae: 0.9550
# Epoch 28/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.7430 - mae: 0.8474
# Epoch 29/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3485 - mae: 0.4306
# Epoch 30/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2671 - mae: 0.3180
# Epoch 31/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.4898 - mae: 0.5665
# Epoch 32/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.4541 - mae: 0.5302
# Epoch 33/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6143 - mae: 0.7170
# Epoch 34/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4465 - mae: 0.5270
# Epoch 35/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4927 - mae: 0.5836
# Epoch 36/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3430 - mae: 0.4059
# Epoch 37/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3364 - mae: 0.3923
# Epoch 38/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5656 - mae: 0.6619
# Epoch 39/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3985 - mae: 0.4703
# Epoch 40/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2773 - mae: 0.3434
# Epoch 41/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2269 - mae: 0.2826
# Epoch 42/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4271 - mae: 0.5132
# Epoch 43/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2591 - mae: 0.3179
# Epoch 44/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.4389 - mae: 0.5392
# Epoch 45/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.3075 - mae: 0.3655
# Epoch 46/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3952 - mae: 0.4806
# Epoch 47/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3083 - mae: 0.3575
# Epoch 48/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4203 - mae: 0.4944
# Epoch 49/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3348 - mae: 0.4099
# Epoch 50/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4626 - mae: 0.5670
# Epoch 51/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.7165 - mae: 0.8615
# Epoch 52/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3442 - mae: 0.4190
# Epoch 53/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4114 - mae: 0.5169
# Epoch 54/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3844 - mae: 0.4629
# Epoch 55/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1508 - mae: 0.1853
# Epoch 56/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5635 - mae: 0.6881
# Epoch 57/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5287 - mae: 0.6229
# Epoch 58/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2773 - mae: 0.3462
# Epoch 59/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.3719 - mae: 0.4519
# Epoch 60/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2646 - mae: 0.3320
# Epoch 61/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4554 - mae: 0.5631
# Epoch 62/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1665 - mae: 0.2015
# Epoch 63/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3415 - mae: 0.4105
# Epoch 64/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.7812 - mae: 0.8716
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 258ms/step
# MAE for this fold: 2.971428632736206
# Epoch 1/150
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 18s 297ms/step - loss: 1.8242 - mae: 1.9643
# Epoch 2/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - loss: 2.3187 - mae: 2.5155
# Epoch 3/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.5557 - mae: 1.7447
# Epoch 4/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.8958 - mae: 2.1122
# Epoch 5/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.8988 - mae: 2.1204
# Epoch 6/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.6050 - mae: 1.8075
# Epoch 7/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.4804 - mae: 1.6884
# Epoch 8/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.5852 - mae: 1.8108
# Epoch 9/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.8715 - mae: 2.0848
# Epoch 10/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.8378 - mae: 1.0007
# Epoch 11/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.2343 - mae: 2.4526
# Epoch 12/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.5765 - mae: 1.7017
# Epoch 13/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.9474 - mae: 3.1610
# Epoch 14/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.0556 - mae: 2.2009
# Epoch 15/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.3030 - mae: 1.4399
# Epoch 16/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.9173 - mae: 1.0432
# Epoch 17/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.2343 - mae: 1.3818
# Epoch 18/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.7401 - mae: 0.8429
# Epoch 19/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.8514 - mae: 0.9798
# Epoch 20/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.7131 - mae: 0.8232
# Epoch 21/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6889 - mae: 0.7725
# Epoch 22/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5285 - mae: 0.6123
# Epoch 23/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.6811 - mae: 0.8114
# Epoch 24/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.5011 - mae: 0.6012
# Epoch 25/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.6224 - mae: 0.7455
# Epoch 26/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3552 - mae: 0.4262
# Epoch 27/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5822 - mae: 0.6835
# Epoch 28/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6277 - mae: 0.7203
# Epoch 29/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6360 - mae: 0.7366
# Epoch 30/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3787 - mae: 0.4374
# Epoch 31/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4871 - mae: 0.5903
# Epoch 32/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.7737 - mae: 0.9056
# Epoch 33/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.4399 - mae: 0.5346
# Epoch 34/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3834 - mae: 0.4748
# Epoch 35/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.4189 - mae: 0.5171
# Epoch 36/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.3768 - mae: 0.4524
# Epoch 37/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.8385 - mae: 0.9954
# Epoch 38/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4390 - mae: 0.5250
# Epoch 39/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6209 - mae: 0.7546
# Epoch 40/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4656 - mae: 0.5899
# Epoch 41/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5601 - mae: 0.6694
# Epoch 42/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6742 - mae: 0.8148
# Epoch 43/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.6863 - mae: 0.8105
# Epoch 44/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3972 - mae: 0.4703
# Epoch 45/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.4070 - mae: 0.4900
# Epoch 46/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.3212 - mae: 0.3991
# Epoch 47/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.7564 - mae: 0.9107
# Epoch 48/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.4021 - mae: 0.5067
# Epoch 49/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.5442 - mae: 0.6575
# Epoch 50/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2858 - mae: 0.3615
# Epoch 51/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3348 - mae: 0.4046
# Epoch 52/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2970 - mae: 0.3777
# Epoch 53/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.4155 - mae: 0.5174
# Epoch 54/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.4509 - mae: 0.5797
# Epoch 55/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4575 - mae: 0.5678
# Epoch 56/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.4946 - mae: 0.6211
# Epoch 57/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3844 - mae: 0.4823
# Epoch 58/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2965 - mae: 0.3688
# Epoch 59/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5155 - mae: 0.6177
# Epoch 60/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4027 - mae: 0.5279
# Epoch 61/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3760 - mae: 0.4626
# Epoch 62/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3477 - mae: 0.4350
# Epoch 63/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3224 - mae: 0.3888
# Epoch 64/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3492 - mae: 0.4038
# Epoch 65/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5639 - mae: 0.6427
# Epoch 66/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.8356 - mae: 0.9114
# Epoch 67/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.3821 - mae: 1.5033
# Epoch 68/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 1.2465 - mae: 1.3522
# Epoch 69/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.7451 - mae: 0.8103
# Epoch 70/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.8019 - mae: 0.8709
# Epoch 71/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3894 - mae: 0.4394
# Epoch 72/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.8836 - mae: 0.9817
# Epoch 73/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5960 - mae: 0.6599
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 257ms/step
# MAE for this fold: 0.0
# Epoch 1/150
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 17s 210ms/step - loss: 1.1815 - mae: 1.2491
# Epoch 2/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 2.9167 - mae: 3.0637
# Epoch 3/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.1195 - mae: 2.2602
# Epoch 4/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.2390 - mae: 2.4180
# Epoch 5/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.0587 - mae: 1.1652
# Epoch 6/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.8924 - mae: 1.0019
# Epoch 7/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.8143 - mae: 1.9570
# Epoch 8/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.2199 - mae: 1.3345
# Epoch 9/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.3071 - mae: 1.4281
# Epoch 10/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.0954 - mae: 1.1739
# Epoch 11/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.1187 - mae: 1.2389
# Epoch 12/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.0188 - mae: 1.1011
# Epoch 13/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.8173 - mae: 1.9893
# Epoch 14/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.8753 - mae: 0.9500
# Epoch 15/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5868 - mae: 0.6499
# Epoch 16/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.9687 - mae: 1.0856
# Epoch 17/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6185 - mae: 0.6958
# Epoch 18/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.5255 - mae: 0.6088
# Epoch 19/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.4766 - mae: 0.5561
# Epoch 20/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.2620 - mae: 1.3629
# Epoch 21/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.7821 - mae: 0.8803
# Epoch 22/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5017 - mae: 0.5942
# Epoch 23/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3533 - mae: 0.4118
# Epoch 24/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.4105 - mae: 0.5070
# Epoch 25/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6419 - mae: 0.7495
# Epoch 26/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3393 - mae: 0.3988
# Epoch 27/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.3610 - mae: 0.4402
# Epoch 28/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.6459 - mae: 0.7763
# Epoch 29/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6237 - mae: 0.7341
# Epoch 30/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4739 - mae: 0.5876
# Epoch 31/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1971 - mae: 0.2402
# Epoch 32/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5036 - mae: 0.6034
# Epoch 33/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6623 - mae: 0.7806
# Epoch 34/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3698 - mae: 0.4406
# Epoch 35/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.6391 - mae: 0.7559
# Epoch 36/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5783 - mae: 0.6843
# Epoch 37/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3636 - mae: 0.4464
# Epoch 38/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6191 - mae: 0.7131
# Epoch 39/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4648 - mae: 0.5578
# Epoch 40/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2516 - mae: 0.3125
# Epoch 41/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2688 - mae: 0.3169
# Epoch 42/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2619 - mae: 0.3030
# Epoch 43/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.3755 - mae: 0.4618
# Epoch 44/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3577 - mae: 0.4353
# Epoch 45/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1875 - mae: 0.2340
# Epoch 46/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4839 - mae: 0.5760
# Epoch 47/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6706 - mae: 0.7273
# Epoch 48/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3760 - mae: 0.4499
# Epoch 49/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4286 - mae: 0.5292
# Epoch 50/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.7208 - mae: 0.8453
# Epoch 51/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.5170 - mae: 0.5927
# Epoch 52/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3415 - mae: 0.4158
# Epoch 53/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4764 - mae: 0.5618
# Epoch 54/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3080 - mae: 0.3995
# Epoch 55/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3187 - mae: 0.3828
# Epoch 56/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3400 - mae: 0.4217
# Epoch 57/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2808 - mae: 0.3402
# Epoch 58/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.6134 - mae: 0.7313
# Epoch 59/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.3537 - mae: 0.4393
# Epoch 60/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2716 - mae: 0.3427
# Epoch 61/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3525 - mae: 0.4315
# Epoch 62/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3145 - mae: 0.3762
# Epoch 63/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.3675 - mae: 0.4370
# Epoch 64/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.2028 - mae: 0.2552
# Epoch 65/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2663 - mae: 0.3138
# Epoch 66/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.2205 - mae: 0.2737
# Epoch 67/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.1184 - mae: 0.1559
# Epoch 68/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1736 - mae: 0.2196
# Epoch 69/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4777 - mae: 0.6201
# Epoch 70/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1764 - mae: 0.2060
# Epoch 71/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2620 - mae: 0.3388
# Epoch 72/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3370 - mae: 0.4359
# Epoch 73/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1528 - mae: 0.1959
# Epoch 74/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.2468 - mae: 0.3130
# Epoch 75/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.5102 - mae: 0.6114
# Epoch 76/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.1843 - mae: 0.2448
# Epoch 77/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2679 - mae: 0.3282
# Epoch 78/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.2714 - mae: 0.3246
# Epoch 79/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1560 - mae: 0.1975
# Epoch 80/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2105 - mae: 0.2699
# Epoch 81/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.5111 - mae: 0.6220
# Epoch 82/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.3408 - mae: 0.4317
# Epoch 83/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2625 - mae: 0.3326
# Epoch 84/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4570 - mae: 0.5959
# Epoch 85/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.1450 - mae: 0.1914
# Epoch 86/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1682 - mae: 0.2195
# Epoch 87/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2707 - mae: 0.3628
# Epoch 88/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3210 - mae: 0.3963
# Epoch 89/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2803 - mae: 0.3547
# Epoch 90/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.1757 - mae: 0.2205
# Epoch 91/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2869 - mae: 0.3953
# Epoch 92/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3233 - mae: 0.4118
# Epoch 93/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.1447 - mae: 0.1797
# Epoch 94/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.6611 - mae: 0.7887
# Epoch 95/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.3800 - mae: 0.4653
# Epoch 96/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.2224 - mae: 0.2838
# Epoch 97/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.2376 - mae: 0.2979
# Epoch 98/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2069 - mae: 0.2765
# Epoch 99/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.3806 - mae: 0.4861
# Epoch 100/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.4522 - mae: 0.5680
# Epoch 101/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2737 - mae: 0.3449
# Epoch 102/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2632 - mae: 0.3588
# Epoch 103/150
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.2749 - mae: 0.3511
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 351ms/step
# MAE for this fold: 3.0271427631378174
# Mean MAE across all folds: 1.7520900547504425
# Epoch 1/200
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 17s 187ms/step - loss: 0.8144 - mae: 0.8820
# Epoch 2/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.7623 - mae: 1.8808
# Epoch 3/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.4426 - mae: 1.6183
# Epoch 4/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.5065 - mae: 1.6951
# Epoch 5/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.8596 - mae: 0.9850
# Epoch 6/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.0918 - mae: 1.2535
# Epoch 7/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.0412 - mae: 1.1550
# Epoch 8/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.5356 - mae: 1.6716
# Epoch 9/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.5669 - mae: 1.6775
# Epoch 10/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.6985 - mae: 0.7829
# Epoch 11/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1.4456 - mae: 1.6164
# Epoch 12/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 1.1709 - mae: 1.2804
# Epoch 13/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4593 - mae: 0.5211
# Epoch 14/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.8192 - mae: 0.9276
# Epoch 15/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.7966 - mae: 0.8765
# Epoch 16/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.9905 - mae: 1.0978
# Epoch 17/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.3676 - mae: 1.5087
# Epoch 18/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.9737 - mae: 1.1050
# Epoch 19/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.6113 - mae: 0.6909
# Epoch 20/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.5540 - mae: 0.6481
# Epoch 21/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4761 - mae: 0.5577
# Epoch 22/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.6667 - mae: 0.7436
# Epoch 23/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.4622 - mae: 0.5471
# Epoch 24/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.5614 - mae: 0.6538
# Epoch 25/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.3323 - mae: 0.4047
# Epoch 26/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.3533 - mae: 0.4255
# Epoch 27/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5141 - mae: 0.6137
# Epoch 28/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.6378 - mae: 0.7374
# Epoch 29/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3688 - mae: 0.4411
# Epoch 30/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.4168 - mae: 0.4952
# Epoch 31/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.4815 - mae: 0.5784
# Epoch 32/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4280 - mae: 0.5358
# Epoch 33/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2602 - mae: 0.3124
# Epoch 34/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.8851 - mae: 0.9990
# Epoch 35/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4245 - mae: 0.5035
# Epoch 36/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.7314 - mae: 0.8192
# Epoch 37/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.5997 - mae: 0.7171
# Epoch 38/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.4507 - mae: 0.5370
# Epoch 39/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.2209 - mae: 0.2674
# Epoch 40/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.9236 - mae: 1.0456
# Epoch 41/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5598 - mae: 0.6970
# Epoch 42/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3903 - mae: 0.4478
# Epoch 43/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.7391 - mae: 0.8496
# Epoch 44/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.4034 - mae: 0.4691
# Epoch 45/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3542 - mae: 0.4264
# Epoch 46/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5256 - mae: 0.6385
# Epoch 47/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3045 - mae: 0.3651
# Epoch 48/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.6821 - mae: 0.8047
# Epoch 49/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2795 - mae: 0.3543
# Epoch 50/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.4932 - mae: 0.5990
# Epoch 51/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.3097 - mae: 0.3756
# Epoch 52/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4098 - mae: 0.4868
# Epoch 53/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5348 - mae: 0.6298
# Epoch 54/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4178 - mae: 0.4959
# Epoch 55/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.3551 - mae: 0.4186
# Epoch 56/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.9980 - mae: 1.1507
# Epoch 57/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.6366 - mae: 0.7780
# Epoch 58/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2344 - mae: 0.2946
# Epoch 59/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5864 - mae: 0.6610
# Epoch 60/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2481 - mae: 0.3070
# Epoch 61/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3087 - mae: 0.3768
# Epoch 62/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2340 - mae: 0.2857
# Epoch 63/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5078 - mae: 0.6260
# Epoch 64/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.2778 - mae: 0.3308
# Epoch 65/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.4723 - mae: 0.5764
# Epoch 66/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5455 - mae: 0.6557
# Epoch 67/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3352 - mae: 0.4102
# Epoch 68/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3609 - mae: 0.4490
# Epoch 69/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3153 - mae: 0.4128
# Epoch 70/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3588 - mae: 0.4329
# Epoch 71/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.9487 - mae: 1.0643
# Epoch 72/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.5377 - mae: 0.6471
# Epoch 73/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5657 - mae: 0.6978
# Epoch 74/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4838 - mae: 0.5716
# Epoch 75/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4054 - mae: 0.4896
# Epoch 76/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4011 - mae: 0.5039
# Epoch 77/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.6336 - mae: 0.7267
# Epoch 78/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5130 - mae: 0.5884
# Epoch 79/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.2784 - mae: 0.3468
# Epoch 80/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4141 - mae: 0.5278
# Epoch 81/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3207 - mae: 0.3861
# Epoch 82/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4500 - mae: 0.5380
# Epoch 83/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2853 - mae: 0.3776
# Epoch 84/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4131 - mae: 0.4904
# Epoch 85/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5545 - mae: 0.6436
# Epoch 86/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.7986 - mae: 0.9465
# Epoch 87/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3284 - mae: 0.3977
# Epoch 88/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2570 - mae: 0.3213
# Epoch 89/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3335 - mae: 0.4136
# Epoch 90/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2969 - mae: 0.3579
# Epoch 91/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3019 - mae: 0.3752
# Epoch 92/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.2355 - mae: 0.2934
# Epoch 93/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.3857 - mae: 0.4637
# Epoch 94/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2555 - mae: 0.3381
# Epoch 95/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3445 - mae: 0.4302
# Epoch 96/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2762 - mae: 0.3364
# Epoch 97/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3228 - mae: 0.4013
# Epoch 98/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5691 - mae: 0.6983
# Epoch 99/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3460 - mae: 0.4358
# Epoch 100/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.2961 - mae: 0.3731
# Epoch 101/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.6384 - mae: 0.7347
# Epoch 102/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5142 - mae: 0.6192
# Epoch 103/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3723 - mae: 0.4302
# Epoch 104/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2438 - mae: 0.3288
# Epoch 105/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2783 - mae: 0.3395
# Epoch 106/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2441 - mae: 0.3135
# Epoch 107/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2951 - mae: 0.3748
# Epoch 108/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.6326 - mae: 0.7351
# Epoch 109/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3642 - mae: 0.4678
# Epoch 110/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5598 - mae: 0.6756
# Epoch 111/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2650 - mae: 0.3396
# Epoch 112/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2914 - mae: 0.3687
# Epoch 113/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3545 - mae: 0.4275
# Epoch 114/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4889 - mae: 0.5834
# Epoch 115/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.3027 - mae: 0.3820
# Epoch 116/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.7009 - mae: 0.8288
# Epoch 117/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2496 - mae: 0.3026
# Epoch 118/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.6156 - mae: 0.7146
# Epoch 119/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.3639 - mae: 0.4540
# Epoch 120/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3037 - mae: 0.3758
# Epoch 121/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.3157 - mae: 0.3866
# Epoch 122/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.3019 - mae: 0.3625
# Epoch 123/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2457 - mae: 0.3015
# Epoch 124/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2584 - mae: 0.3205
# Epoch 125/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2995 - mae: 0.3517
# Epoch 126/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.2747 - mae: 0.3315
# Epoch 127/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5048 - mae: 0.6073
# Epoch 128/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.2294 - mae: 0.2695
# Epoch 129/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4783 - mae: 0.5543
# Epoch 130/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.6384 - mae: 0.7180
# Epoch 131/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.6579 - mae: 0.7716
# Epoch 132/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4215 - mae: 0.4997
# Epoch 133/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.3813 - mae: 0.4476
# Epoch 134/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.8625 - mae: 0.9586
# Epoch 135/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.2896 - mae: 0.3586
# Epoch 136/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.4212 - mae: 0.4956
# Epoch 137/200
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.5859 - mae: 0.6805
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error

# Mount Google Drive (if using Colab)
from google.colab import drive
drive.mount('/content/drive')

# Load and preprocess data
platform_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Capstone Related/platform_position_1.csv")
satellite_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Capstone Related/satellite_positions_1.csv")

platform_df["Time"] = pd.to_datetime(platform_df["Time"], format="%d-%b-%Y %H:%M:%S", errors="coerce")
satellite_df["Time"] = pd.to_datetime(satellite_df["Time"], format="%d-%b-%Y %H:%M:%S", errors="coerce")

platform_df = platform_df.dropna(subset=["Time"])
satellite_df = satellite_df.dropna(subset=["Time"])

# Merge datasets based on time
merged_df = pd.merge(satellite_df, platform_df, on="Time", suffixes=("_sat", "_plat"))

# Extract time-based feature
merged_df["MinuteOfDay"] = merged_df["Time"].dt.hour * 60 + merged_df["Time"].dt.minute

# Select features and target variable
features = ["Longitude_sat", "Latitude_sat", "MinuteOfDay"]
target = "NumConnections"
print(merged_df[features].head())
print(merged_df[target].head())

# Normalize the features
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(merged_df[features])

# Define sequence length
sequence_length = 60

# Create time-series sequences
generator = TimeseriesGenerator(scaled_features, merged_df[target].values, length=sequence_length, batch_size=64)

# Define LSTM model
def create_lstm_model():
    model = Sequential([
        BatchNormalization(input_shape=(sequence_length, len(features))),
        LSTM(256, activation="relu", return_sequences=True),  # Using LSTM instead of GRU or RNN
        Dropout(0.2),
        LSTM(128, activation="relu"),  # Adding a second LSTM layer
        Dropout(0.2),
        Dense(1)
    ])
    optimizer = Adam(learning_rate=1e-4, decay=1e-6)
    model.compile(optimizer=optimizer, loss="huber", metrics=["mae"])
    return model

# Cross-validation using TimeSeriesSplit
tscv = TimeSeriesSplit(n_splits=5)
mae_scores = []

for train_index, test_index in tscv.split(scaled_features):
    train_data, test_data = scaled_features[train_index], scaled_features[test_index]
    train_target, test_target = merged_df[target].values[train_index], merged_df[target].values[test_index]

    train_generator = TimeseriesGenerator(train_data, train_target, length=sequence_length, batch_size=64)
    test_generator = TimeseriesGenerator(test_data, test_target, length=sequence_length, batch_size=64)

    model = create_lstm_model()
    history = model.fit(train_generator, epochs=150, verbose=1, callbacks=[EarlyStopping(monitor='loss', patience=15, restore_best_weights=True)])

    predictions = model.predict(test_generator)
    mae = mean_absolute_error(test_target[sequence_length:], predictions)
    mae_scores.append(mae)
    print(f"MAE for this fold: {mae}")

print(f"Mean MAE across all folds: {np.mean(mae_scores)}")

# Train the final model on the entire dataset
final_model = create_lstm_model()
history = final_model.fit(generator, epochs=200, verbose=1, callbacks=[EarlyStopping(monitor='loss', patience=15, restore_best_weights=True)])

# Plot training loss
plt.plot(history.history["loss"], label="Loss")
plt.plot(history.history["mae"], label="MAE")
plt.legend()
plt.title("Training Performance")
plt.show()

# Make predictions
predictions = final_model.predict(generator)

# Plot predictions vs actual values
plt.figure(figsize=(10, 5))
plt.plot(merged_df[target].values[sequence_length:], label="Actual")
plt.plot(predictions, label="Predicted", linestyle="dashed")
plt.legend()
plt.title("LSTM Predictions vs Actual")
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Longitude_sat  Latitude_sat  MinuteOfDay
# 0       3.164754   -158.684943            1
# 1       3.164754   -158.684943            1
# 2       3.164754   -158.684943            1
# 3       3.164754   -158.684943            1
# 4       3.164754   -158.684943            1
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: NumConnections, dtype: int64
# Epoch 1/150
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 11s 269ms/step - loss: 1.6293 - mae: 1.7203
# Epoch 2/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.2844 - mae: 2.4046
# Epoch 3/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.1229 - mae: 2.2528
# Epoch 4/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.3980 - mae: 4.6311
# Epoch 5/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.3644 - mae: 2.5360
# Epoch 6/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.7600 - mae: 5.0083
# Epoch 7/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 4.3606 - mae: 4.6015
# Epoch 8/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.9550 - mae: 2.1630
# Epoch 9/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.6527 - mae: 3.9064
# Epoch 10/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.2704 - mae: 2.5062
# Epoch 11/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.2623 - mae: 2.5236
# Epoch 12/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.5306 - mae: 3.8470
# Epoch 13/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.5707 - mae: 1.7908
# Epoch 14/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8346 - mae: 2.0287
# Epoch 15/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.4650 - mae: 1.6368
# Epoch 16/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3754 - mae: 1.5574
# Epoch 17/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3548 - mae: 1.5104
# Epoch 18/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.7915 - mae: 4.0458
# Epoch 19/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.4133 - mae: 2.6352
# Epoch 20/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.6495 - mae: 2.9502
# Epoch 21/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7319 - mae: 0.9426
# Epoch 22/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2110 - mae: 1.4020
# Epoch 23/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1270 - mae: 2.3766
# Epoch 24/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6301 - mae: 1.9182
# Epoch 25/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.3437 - mae: 1.5982
# Epoch 26/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 75.7236 - mae: 75.9619
# Epoch 27/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.3082 - mae: 2.5096
# Epoch 28/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.8720 - mae: 1.0154
# Epoch 29/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.6002 - mae: 1.7662
# Epoch 30/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 3.4518 - mae: 3.6937
# Epoch 31/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2210 - mae: 1.3770
# Epoch 32/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0274 - mae: 1.2001
# Epoch 33/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8459 - mae: 1.0070
# Epoch 34/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7384 - mae: 0.8975
# Epoch 35/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.4847 - mae: 3.7472
# Epoch 36/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9549 - mae: 1.0811
# Epoch 37/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9924 - mae: 1.1112
# Epoch 38/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0193 - mae: 1.1731
# Epoch 39/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.4333 - mae: 1.6106
# Epoch 40/150
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9280 - mae: 1.0790
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step
# MAE for this fold: 21254894.0
# Epoch 1/150
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 10s 207ms/step - loss: 2.5835 - mae: 2.7111
# Epoch 2/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3921 - mae: 1.4982
# Epoch 3/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.2484 - mae: 1.3643
# Epoch 4/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.4724 - mae: 1.6420
# Epoch 5/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1888 - mae: 1.3534
# Epoch 6/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7424 - mae: 1.9244
# Epoch 7/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.5461 - mae: 3.8347
# Epoch 8/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.8775 - mae: 3.1422
# Epoch 9/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0228 - mae: 1.1679
# Epoch 10/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8211 - mae: 2.0168
# Epoch 11/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1680 - mae: 1.3777
# Epoch 12/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0779 - mae: 1.2547
# Epoch 13/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9774 - mae: 1.2052
# Epoch 14/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7392 - mae: 1.9399
# Epoch 15/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.2968 - mae: 2.4762
# Epoch 16/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3588 - mae: 1.5141
# Epoch 17/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8593 - mae: 2.0369
# Epoch 18/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8536 - mae: 1.0009
# Epoch 19/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.6932 - mae: 2.9142
# Epoch 20/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0483 - mae: 1.1898
# Epoch 21/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.6707 - mae: 2.8857
# Epoch 22/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0387 - mae: 1.2022
# Epoch 23/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.4655 - mae: 8.6580
# Epoch 24/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 889.8894 - mae: 890.0552
# Epoch 25/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4066 - mae: 1.6226
# Epoch 26/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.8473 - mae: 3.1380
# Epoch 27/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.9288 - mae: 1.1416
# Epoch 28/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4684 - mae: 1.6515
# Epoch 29/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.6342 - mae: 0.7975
# Epoch 30/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1488 - mae: 1.3271
# Epoch 31/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.9255 - mae: 1.1001
# Epoch 32/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1027 - mae: 2.3756
# Epoch 33/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.7620 - mae: 0.9550
# Epoch 34/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0126 - mae: 2.2436
# Epoch 35/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5563 - mae: 1.7812
# Epoch 36/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.7130 - mae: 1.8829
# Epoch 37/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8356 - mae: 2.0382
# Epoch 38/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4347 - mae: 1.6356
# Epoch 39/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3333 - mae: 1.5516
# Epoch 40/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3234 - mae: 1.4833
# Epoch 41/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3114 - mae: 1.5331
# Epoch 42/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.8398 - mae: 0.9891
# Epoch 43/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4888 - mae: 0.6437
# Epoch 44/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5674 - mae: 0.7197
# Epoch 45/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.6844 - mae: 0.8459
# Epoch 46/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.6172 - mae: 1.8411
# Epoch 47/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.4978 - mae: 1.6947
# Epoch 48/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.2492 - mae: 1.4274
# Epoch 49/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.8616 - mae: 1.0024
# Epoch 50/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3797 - mae: 1.5694
# Epoch 51/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9050 - mae: 1.0693
# Epoch 52/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.8679 - mae: 1.0285
# Epoch 53/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6881 - mae: 0.8261
# Epoch 54/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0856 - mae: 1.2652
# Epoch 55/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9552 - mae: 1.1441
# Epoch 56/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8776 - mae: 1.0818
# Epoch 57/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9797 - mae: 1.1667
# Epoch 58/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.4798 - mae: 0.6133
# Epoch 59/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.3793 - mae: 0.5081
# Epoch 60/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5009 - mae: 0.6358
# Epoch 61/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5896 - mae: 0.7363
# Epoch 62/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6562 - mae: 0.7750
# Epoch 63/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8930 - mae: 1.0492
# Epoch 64/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8132 - mae: 0.9760
# Epoch 65/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.6332 - mae: 0.8060
# Epoch 66/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.6142 - mae: 0.7431
# Epoch 67/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.5957 - mae: 0.7384
# Epoch 68/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.6638 - mae: 0.7776
# Epoch 69/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.8183 - mae: 0.9703
# Epoch 70/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.9100 - mae: 1.1020
# Epoch 71/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4865 - mae: 0.6550
# Epoch 72/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.9908 - mae: 1.1647
# Epoch 73/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7144 - mae: 0.8608
# Epoch 74/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.3635 - mae: 0.5007
# Epoch 75/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5453 - mae: 0.6767
# Epoch 76/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0345 - mae: 1.2353
# Epoch 77/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9751 - mae: 1.1604
# Epoch 78/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4956 - mae: 0.6224
# Epoch 79/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5058 - mae: 0.6610
# Epoch 80/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.5994 - mae: 0.7660
# Epoch 81/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4840 - mae: 0.6428
# Epoch 82/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7448 - mae: 0.8834
# Epoch 83/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2205 - mae: 0.3224
# Epoch 84/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2554 - mae: 0.3766
# Epoch 85/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2222 - mae: 0.3492
# Epoch 86/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3611 - mae: 0.4987
# Epoch 87/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4738 - mae: 0.5993
# Epoch 88/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4314 - mae: 0.5432
# Epoch 89/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.3124 - mae: 0.4244
# Epoch 90/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7059 - mae: 0.9309
# Epoch 91/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.7406 - mae: 0.9028
# Epoch 92/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.4287 - mae: 0.5625
# Epoch 93/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.8732 - mae: 1.0775
# Epoch 94/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1503 - mae: 0.2459
# Epoch 95/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.4362 - mae: 0.5441
# Epoch 96/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2440 - mae: 0.3710
# Epoch 97/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2253 - mae: 0.3267
# Epoch 98/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6659 - mae: 0.8137
# Epoch 99/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4971 - mae: 0.6566
# Epoch 100/150
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.2811 - mae: 0.3769
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# MAE for this fold: 2696858112.0
# Epoch 1/150
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - loss: 2.2329 - mae: 2.3516
# Epoch 2/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 1.6021 - mae: 1.7294
# Epoch 3/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.6653 - mae: 2.8624
# Epoch 4/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1651 - mae: 2.3712
# Epoch 5/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8371 - mae: 2.0150
# Epoch 6/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.7394 - mae: 2.9967
# Epoch 7/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0713 - mae: 1.2110
# Epoch 8/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4320 - mae: 1.6465
# Epoch 9/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2977 - mae: 1.5055
# Epoch 10/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5088 - mae: 1.6951
# Epoch 11/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.8951 - mae: 1.0890
# Epoch 12/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1939.6178 - mae: 1939.8412
# Epoch 13/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4231 - mae: 1.5892
# Epoch 14/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3925 - mae: 1.5936
# Epoch 15/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2205 - mae: 1.3952
# Epoch 16/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8607 - mae: 2.0781
# Epoch 17/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5667 - mae: 1.7554
# Epoch 18/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.5470 - mae: 2.7627
# Epoch 19/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5873 - mae: 1.8069
# Epoch 20/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.2451 - mae: 2.4831
# Epoch 21/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1841 - mae: 1.3935
# Epoch 22/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.5410 - mae: 2.7770
# Epoch 23/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2281 - mae: 1.3944
# Epoch 24/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7489 - mae: 1.9516
# Epoch 25/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.9330 - mae: 1.0940
# Epoch 26/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.0344 - mae: 3.2960
# Epoch 27/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4529 - mae: 1.6765
# Epoch 28/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5359 - mae: 1.7441
# Epoch 29/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.8311 - mae: 2.0751
# Epoch 30/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5384 - mae: 1.7408
# Epoch 31/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6880 - mae: 1.9014
# Epoch 32/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7578 - mae: 1.9654
# Epoch 33/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7129 - mae: 1.9386
# Epoch 34/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9519 - mae: 2.2068
# Epoch 35/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5533 - mae: 1.7486
# Epoch 36/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6898 - mae: 1.9239
# Epoch 37/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3906 - mae: 1.5681
# Epoch 38/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4094 - mae: 1.6262
# Epoch 39/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9320 - mae: 2.1175
# Epoch 40/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.4604 - mae: 2.6901
# Epoch 41/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.8648 - mae: 1.0297
# Epoch 42/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.1203 - mae: 2.3562
# Epoch 43/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6869 - mae: 1.8963
# Epoch 44/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2937 - mae: 1.4662
# Epoch 45/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.8104 - mae: 0.9523
# Epoch 46/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.1248 - mae: 1.3012
# Epoch 47/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.8471 - mae: 0.9916
# Epoch 48/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.8361 - mae: 1.0265
# Epoch 49/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.9284 - mae: 1.0668
# Epoch 50/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0334 - mae: 1.2005
# Epoch 51/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4398 - mae: 1.6162
# Epoch 52/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.8602 - mae: 1.0310
# Epoch 53/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.7046 - mae: 0.8597
# Epoch 54/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.8102 - mae: 0.9787
# Epoch 55/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.7625 - mae: 0.9203
# Epoch 56/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.6967 - mae: 0.8393
# Epoch 57/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.6866 - mae: 0.8038
# Epoch 58/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0825 - mae: 1.2434
# Epoch 59/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5083 - mae: 0.6695
# Epoch 60/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5311 - mae: 0.6741
# Epoch 61/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.6022 - mae: 0.7455
# Epoch 62/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.6406 - mae: 0.8097
# Epoch 63/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4994 - mae: 0.6199
# Epoch 64/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4390 - mae: 0.5595
# Epoch 65/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.7877 - mae: 0.9603
# Epoch 66/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5483 - mae: 0.6716
# Epoch 67/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.3600 - mae: 0.4687
# Epoch 68/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.6801 - mae: 0.8347
# Epoch 69/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2899 - mae: 1.4651
# Epoch 70/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.7707 - mae: 0.8922
# Epoch 71/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4391 - mae: 0.5666
# Epoch 72/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4358 - mae: 0.5615
# Epoch 73/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.3677 - mae: 0.5009
# Epoch 74/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5373 - mae: 0.6670
# Epoch 75/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.4816 - mae: 0.5897
# Epoch 76/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5459 - mae: 0.6893
# Epoch 77/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.8787 - mae: 1.0343
# Epoch 78/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2704 - mae: 0.3607
# Epoch 79/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.8426 - mae: 1.0240
# Epoch 80/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.8588 - mae: 1.0231
# Epoch 81/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5669 - mae: 0.6764
# Epoch 82/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5036 - mae: 0.6495
# Epoch 83/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5811 - mae: 0.7200
# Epoch 84/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2762 - mae: 0.3707
# Epoch 85/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4488 - mae: 0.5748
# Epoch 86/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4259 - mae: 0.5547
# Epoch 87/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5954 - mae: 0.7375
# Epoch 88/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.5206 - mae: 0.6642
# Epoch 89/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.8255 - mae: 0.9693
# Epoch 90/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.4979 - mae: 0.6282
# Epoch 91/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.4296 - mae: 0.5631
# Epoch 92/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4680 - mae: 0.5892
# Epoch 93/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.7410 - mae: 0.8753
# Epoch 94/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4208 - mae: 0.5470
# Epoch 95/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.5272 - mae: 0.6420
# Epoch 96/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1940 - mae: 0.2876
# Epoch 97/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4324 - mae: 0.5596
# Epoch 98/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.9248 - mae: 1.1237
# Epoch 99/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 66.1711 - mae: 66.3474
# Epoch 100/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.8531 - mae: 1.0255
# Epoch 101/150
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.4163 - mae: 0.5265
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step
# MAE for this fold: 19716202496.0
# Epoch 1/150
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 83ms/step - loss: 2.6299 - mae: 2.7786
# Epoch 2/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9681 - mae: 2.1297
# Epoch 3/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3428 - mae: 1.5349
# Epoch 4/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.1978 - mae: 1.3990
# Epoch 5/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5164 - mae: 1.7755
# Epoch 6/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.2423 - mae: 2.5157
# Epoch 7/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.6604 - mae: 0.7963
# Epoch 8/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.4349 - mae: 2.7057
# Epoch 9/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3480 - mae: 2.5460
# Epoch 10/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1587 - mae: 1.3311
# Epoch 11/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.5037 - mae: 2.7729
# Epoch 12/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0705 - mae: 1.2633
# Epoch 13/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.9606 - mae: 1.1736
# Epoch 14/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4297 - mae: 1.6787
# Epoch 15/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3474 - mae: 1.5824
# Epoch 16/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18353.7969 - mae: 18354.0664
# Epoch 17/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9741 - mae: 2.1568
# Epoch 18/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.4993 - mae: 2.7175
# Epoch 19/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7469 - mae: 1.9279
# Epoch 20/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8526 - mae: 2.0433
# Epoch 21/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.2119 - mae: 2.4189
# Epoch 22/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5955 - mae: 1.7721
# Epoch 23/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9593 - mae: 2.1690
# Epoch 24/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5087 - mae: 1.7001
# Epoch 25/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9182 - mae: 2.1478
# Epoch 26/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9635 - mae: 2.1840
# Epoch 27/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6062 - mae: 1.8097
# Epoch 28/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.2268 - mae: 2.4849
# Epoch 29/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7623 - mae: 2.0028
# Epoch 30/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2788 - mae: 1.5188
# Epoch 31/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5003 - mae: 1.7182
# Epoch 32/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5408 - mae: 1.7815
# Epoch 33/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.0661 - mae: 2.3432
# Epoch 34/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.5196 - mae: 2.7899
# Epoch 35/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4768 - mae: 1.6818
# Epoch 36/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2936 - mae: 1.5494
# Epoch 37/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.5811 - mae: 2.8986
# Epoch 38/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 975.4040 - mae: 975.6891
# Epoch 39/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 18.5598 - mae: 18.7871
# Epoch 40/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 401.4254 - mae: 401.6279
# Epoch 41/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.5326 - mae: 8.7606
# Epoch 42/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 169.6931 - mae: 169.8941
# Epoch 43/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 35.7072 - mae: 35.9156
# Epoch 44/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.7235 - mae: 6.8811
# Epoch 45/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 25.3199 - mae: 25.4931
# Epoch 46/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 63.6086 - mae: 63.7814
# Epoch 47/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 102.3082 - mae: 102.5270
# Epoch 48/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 95.8214 - mae: 96.0437
# Epoch 49/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 136.3741 - mae: 136.5667
# Epoch 50/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 166.3542 - mae: 166.5058
# Epoch 51/150
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 83.6286 - mae: 83.8000
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step
# MAE for this fold: 40868.2734375
# Epoch 1/150
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - loss: 1.8169 - mae: 1.9336
# Epoch 2/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4862 - mae: 1.6358
# Epoch 3/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2358 - mae: 1.3690
# Epoch 4/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3877 - mae: 2.6021
# Epoch 5/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5432 - mae: 1.7370
# Epoch 6/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2211 - mae: 1.4195
# Epoch 7/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.5925 - mae: 1.8120
# Epoch 8/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8487 - mae: 2.0311
# Epoch 9/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3219 - mae: 2.5434
# Epoch 10/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8103 - mae: 2.0063
# Epoch 11/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0585 - mae: 1.2311
# Epoch 12/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2679 - mae: 1.4632
# Epoch 13/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1371 - mae: 1.3258
# Epoch 14/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1349 - mae: 2.3553
# Epoch 15/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5097 - mae: 1.6900
# Epoch 16/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.1277 - mae: 1.3263
# Epoch 17/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2216 - mae: 1.4202
# Epoch 18/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7657 - mae: 1.9409
# Epoch 19/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2466 - mae: 1.4658
# Epoch 20/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2325 - mae: 1.3867
# Epoch 21/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5118 - mae: 1.6431
# Epoch 22/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0451 - mae: 1.1948
# Epoch 23/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7047 - mae: 1.8909
# Epoch 24/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7211 - mae: 1.9432
# Epoch 25/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.8299 - mae: 2.0158
# Epoch 26/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 32126.1465 - mae: 32126.2988
# Epoch 27/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9542293.0000 - mae: 9542293.0000
# Epoch 28/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3785 - mae: 1.5090
# Epoch 29/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6290 - mae: 1.7739
# Epoch 30/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9089 - mae: 2.0742
# Epoch 31/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5775 - mae: 1.7205
# Epoch 32/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7708 - mae: 1.9308
# Epoch 33/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4593 - mae: 1.6002
# Epoch 34/150
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 2.4117 - mae: 2.6065
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# MAE for this fold: 14142647.0
# Mean MAE across all folds: 4489699803.454687
# Epoch 1/200
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/normalization/batch_normalization.py:142: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - loss: 1.8069 - mae: 1.9261
# Epoch 2/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1023 - mae: 2.2824
# Epoch 3/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6335 - mae: 1.8366
# Epoch 4/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5100 - mae: 1.7076
# Epoch 5/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1058 - mae: 2.3538
# Epoch 6/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5796 - mae: 1.7874
# Epoch 7/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3063 - mae: 1.4818
# Epoch 8/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.1671 - mae: 1.3251
# Epoch 9/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.3774 - mae: 1.5732
# Epoch 10/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.3205 - mae: 1.5350
# Epoch 11/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.6601 - mae: 1.8899
# Epoch 12/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2467 - mae: 1.4512
# Epoch 13/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4252 - mae: 1.6169
# Epoch 14/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.9711 - mae: 1.1438
# Epoch 15/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7515 - mae: 1.9506
# Epoch 16/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3367 - mae: 1.5374
# Epoch 17/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.5380 - mae: 1.7447
# Epoch 18/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.4357 - mae: 1.6492
# Epoch 19/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.3975 - mae: 1.6158
# Epoch 20/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8170 - mae: 2.0392
# Epoch 21/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.3703 - mae: 6.5876
# Epoch 22/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 18.5422 - mae: 18.7651
# Epoch 23/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6005 - mae: 1.7788
# Epoch 24/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.9835 - mae: 2.1591
# Epoch 25/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.6537 - mae: 1.8098
# Epoch 26/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.8278 - mae: 1.9887
# Epoch 27/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 1.6934 - mae: 1.8814
# Epoch 28/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.2667 - mae: 2.4636
# Epoch 29/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 1.8281 - mae: 2.0042
# Epoch 30/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9098 - mae: 2.0883
# Epoch 31/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3411 - mae: 2.5500
# Epoch 32/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6232 - mae: 1.8161
# Epoch 33/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 1.3685 - mae: 1.5197
# Epoch 34/200
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.2537 - mae: 2.4411
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from google.colab import drive
drive.mount('/content/drive')

# Load and preprocess data
platform_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Capstone Related/platform_position_exp.csv")
satellite_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Capstone Related/satellite_positions_exp.csv")

platform_df["Time"] = pd.to_datetime(platform_df["Time"], format="%d-%b-%Y %H:%M:%S", errors="coerce")
satellite_df["Time"] = pd.to_datetime(satellite_df["Time"], format="%d-%b-%Y %H:%M:%S", errors="coerce")

platform_df = platform_df.dropna(subset=["Time"])
satellite_df = satellite_df.dropna(subset=["Time"])

# Merge datasets based on time
merged_df = pd.merge(satellite_df, platform_df, on="Time", suffixes=("_sat", "_plat"))

# Extract time-based feature
merged_df["MinuteOfDay"] = merged_df["Time"].dt.hour * 60 + merged_df["Time"].dt.minute

# Select features and target variable
#features = ["Longitude_sat", "Latitude_sat", "MinuteOfDay"]
#target = "NumConnections"
# Prepare the dataset (drop Time column as it's not numeric)
#X = merged_df[features]
#y = merged_df[target]
num_lags = 50  # You can adjust this

# Create lag features for NumConnections
for lag in range(1, num_lags + 1):
    merged_df[f"NumConnections_lag_{lag}"] = merged_df["NumConnections"].shift(lag)

# Drop rows with NaN values after shifting
merged_df = merged_df.dropna()

# Re-define the feature set after adding lags
features = ["Longitude_sat", "Latitude_sat", "MinuteOfDay"] + [f"NumConnections_lag_{lag}" for lag in range(1, num_lags + 1)]
target = "NumConnections"
# Prepare the dataset (drop Time column as it's not numeric)
X = merged_df[features]
y = merged_df[target]
# Split into training and testing sets (ordered for time series)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Initialize and train a Decision Tree Regressor
dt_regressor = DecisionTreeRegressor(max_depth=10, random_state=42)
dt_regressor.fit(X_train, y_train)

# Predict on both training and testing sets
dt_train_preds = dt_regressor.predict(X_train)
dt_test_preds = dt_regressor.predict(X_test)

# Concatenate predictions to match full length of original y
dt_full_preds = np.concatenate([dt_train_preds, dt_test_preds])

# Evaluate only on test set
dt_mae = mean_absolute_error(y_test, dt_test_preds)
print(f"Decision Tree MAE: {dt_mae}")

# Plot predictions vs actual values over full range
plt.figure(figsize=(14, 6))
plt.plot(y.values, label="Actual", alpha=0.7)
plt.plot(dt_full_preds, label="Predicted", linestyle="dashed")
plt.legend()
plt.title("Decision Tree Predictions vs Actual (Full Range)")
plt.xlabel("Time Step")
plt.ylabel(target)
plt.tight_layout()
plt.show()
# Out:
# Mounted at /content/drive
# Decision Tree MAE: 0.31654676258992803

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from google.colab import drive
drive.mount('/content/drive')

# Load and preprocess data
platform_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Capstone Related/platform_position_exp.csv")
satellite_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Capstone Related/satellite_positions_exp.csv")

platform_df["Time"] = pd.to_datetime(platform_df["Time"], format="%d-%b-%Y %H:%M:%S", errors="coerce")
satellite_df["Time"] = pd.to_datetime(satellite_df["Time"], format="%d-%b-%Y %H:%M:%S", errors="coerce")

platform_df = platform_df.dropna(subset=["Time"])
satellite_df = satellite_df.dropna(subset=["Time"])

# Merge datasets based on time
merged_df = pd.merge(satellite_df, platform_df, on="Time", suffixes=("_sat", "_plat"))

# Extract time-based feature
merged_df["MinuteOfDay"] = merged_df["Time"].dt.hour * 60 + merged_df["Time"].dt.minute

# Select features and target variable
#features = ["Longitude_sat", "Latitude_sat", "MinuteOfDay"]
#target = "NumConnections"
# Prepare the dataset (drop Time column as it's not numeric)
#X = merged_df[features]
#y = merged_df[target]
num_lags = 50  # You can adjust this

# Create lag features for NumConnections
for lag in range(1, num_lags + 1):
    merged_df[f"NumConnections_lag_{lag}"] = merged_df["NumConnections"].shift(lag)

# Drop rows with NaN values after shifting
merged_df = merged_df.dropna()

# Re-define the feature set after adding lags
features = ["Longitude_sat", "Latitude_sat", "MinuteOfDay"] + [f"NumConnections_lag_{lag}" for lag in range(1, num_lags + 1)]
target = "NumConnections"
# Prepare the dataset (drop Time column as it's not numeric)
X = merged_df[features]
y = merged_df[target]
# Prepare the dataset
X = merged_df[features]
y = merged_df[target]

# Split into training and testing sets (maintain time order)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Initialize and train the Random Forest Regressor
rf_regressor = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42)
rf_regressor.fit(X_train, y_train)

# Predict on both training and testing sets
rf_train_preds = rf_regressor.predict(X_train)
rf_test_preds = rf_regressor.predict(X_test)

# Concatenate full predictions for entire dataset
rf_full_preds = np.concatenate([rf_train_preds, rf_test_preds])

# Evaluate on test set
rf_mae = mean_absolute_error(y_test, rf_test_preds)
print(f"Random Forest MAE: {rf_mae}")

# Plot predictions vs actual values across full dataset
plt.figure(figsize=(14, 6))
plt.plot(y.values, label="Actual", alpha=0.7)
plt.plot(rf_full_preds, label="Predicted", linestyle="dashed")
plt.legend()
plt.title("Random Forest Predictions vs Actual (Full Range)")
plt.xlabel("Time Step")
plt.ylabel(target)
plt.tight_layout()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Random Forest MAE: 0.2319784172661871
